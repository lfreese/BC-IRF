# %%
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import sys
sys.path.insert(0, '/net/fs11/d0/emfreese/BC-IRF/')
import utils

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
xr.open_dataset('../raw_data_inputs/sands_2020_BC_temp/N2000_10xBCemEA_ens1.ANN.2020-2099.nc')
# Out:
# <xarray.Dataset>
# Dimensions:    (slat: 95, lat: 96, lon: 144, slon: 144, lev: 26, nhyi: 27, nhym: 26, ilev: 27, time: 1, nb2: 2)
# Coordinates:
#   * slat       (slat) float64 -89.05 -87.16 -85.26 -83.37 ... 85.26 87.16 89.05
#   * lat        (lat) float64 -90.0 -88.11 -86.21 -84.32 ... 86.21 88.11 90.0
#   * lon        (lon) float64 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#   * slon       (slon) float64 -1.25 1.25 3.75 6.25 ... 348.8 351.2 353.8 356.2
#   * lev        (lev) float64 3.545 7.389 13.97 23.94 ... 867.2 929.6 970.6 992.6
#   * ilev       (ilev) float64 2.194 4.895 9.882 18.05 ... 956.0 985.1 1e+03
#   * time       (time) object 2100-01-01 00:00:00
# Dimensions without coordinates: nhyi, nhym, nb2
# Data variables: (12/234)
#     hyai       (nhyi) float64 ...
#     hybi       (nhyi) float64 ...
#     hyam       (nhym) float64 ...
#     hybm       (nhym) float64 ...
#     time_bnds  (time, nb2) object ...
#     w_stag     (slat) float64 ...
# ...
